# %% [markdown]
# # **PROJECT TITLE:SOCIAL MEDIA VS PRODUCTIVITY**

# %% [markdown]
# # **STEP 1: Data Loading And Initial Overview**

# %% [markdown]
# This project lies at the intersection of data analysis and human behavior, focusing on how digital habits especially social media usage affect productivity, stress, and overall well-being.
#
# 🎯 **Objective**:
# The main objective of this project is to analyze the relationship between social media usage and productivity levels using exploratory data analysis (EDA)and visualizations.
#
# **Specific goals include**:
# * Understanding patterns in daily social media usage.
# * Comparing perceived productivity vs actual productivity.
# * Analyzing the impact of screen time, sleep, and stress on work performance.
# * Identifying correlations and trends that influence productivity.
# * Gaining insights that can help promote healthier digital habits
#
# **Dataset:**
#
# Social Media and Productivity Dataset containing 30,000 records with 19 features but here i am taking only 17 columns, including digital behavior metrics, productivity indicators, well-being factors, and usage patterns. This dataset is used to analyze the impact of social media usage on productivity through exploratory data analysis and visualization.

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-25c1a2b2-600c-467e-91e3-bfb71d12e9d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25c1a2b2-600c-467e-91e3-bfb71d12e9d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## **1.1 Data Source And Loading**
#
# **Data source:** This dataset was collected from an open-source data platform and represents simulated/real-world data related to social media usage and productivity.
#
# **Source Link**:https://www.kaggle.com/datasets/mahdimashayekhi/social-media-vs-productivity
#
# **Dataset Description**:
#
# The dataset contains individual-level behavioral, demographic, and productivity-related information.
#
# Key attributes include:
#
# *  Demographics: age, gender, job_type
# * Social media behavior: daily_social_media_time, social_platform_preference, number_of_notifications
# * Productivity metrics: perceived_productivity_score, actual_productivity_score
# * Wellbeing factors: stress_level, sleep_hours, screen_time_before_sleep
# * Digital habits: uses_focus_apps, has_digital_wellbeing_enabled
# * Work-life balance: work_hours_per_day, weekly_offline_hours
# * Mental health & satisfaction: days_feeling_burnout_per_month, job_satisfaction_score
#
# **Initial Data Exploration**:
#
# This stage focuses on reviewing a small portion of the dataset to understand how the data is organized. By observing the first few records, we can:
#
# Understand the layout of rows and columns
# Observe typical values stored in each feature
# Identify whether columns contain numerical or categorical data
# Spot any immediate irregularities or missing information
# The df.head() function is used to display a preview of the dataset, showing the top five rows by default. If needed, the number of displayed rows can be adjusted by passing an integer value to df.head(n).

# %%
import pandas as pd

df = pd.read_csv("SOCIAL MEDIA VS PRODUCTIVITY ORG.csv")  # loading dataset
df.head()
# Out:
#    age  gender    job_type  daily_social_media_time  \
# 0   56    Male  Unemployed                 4.180940
# 1   46    Male      Health                 3.249603
# 2   32    Male     Finance                      NaN
# 3   60  Female  Unemployed                      NaN
# 4   25    Male          IT                      NaN
#
#   social_platform_preference  number_of_notifications  work_hours_per_day  \
# 0                   Facebook                       61            6.753558
# 1                    Twitter                       59            9.169296
# 2                    Twitter                       57            7.910952
# 3                   Facebook                       59            6.355027
# 4                   Telegram                       66            6.214096
#
#    perceived_productivity_score  actual_productivity_score  stress_level  \
# 0                      8.040464                   7.291555           4.0
# ...

# %% [markdown]
# ### **Dataset Dimensions**
#
# * The `df.shape` attribute returns the size of the dataset.
# * Displays the number of rows and columns as a tuple `(rows, columns)`.
# * Helps quickly understand the dataset’s scale and structure.
# * Useful for planning data cleaning, analysis, and visualization steps.

# %%
df.shape # number of rows and columns
# Out:
# (3000, 17)

# %% [markdown]
# The dataset is randomly sampled to retain a subset of 3,000 rows using the sample() function. Setting random_state=42 ensures reproducibility, so the same subset is selected each time the code is run. The reset_index(drop=True) method reindexes the resulting DataFrame, removing the old index and maintaining a clean, consecutive index for further analysis.

# %%
df = df.sample(n=3000, random_state=42).reset_index(drop=True) #remove rows and keep it as prefered number here it is 3000

# %% [markdown]
# ## **1.2 Column Information and Data Types**
#
# * The `df.info()` function provides a concise summary of the DataFrame.
# * Displays the total number of entries (rows) and columns.
# * Shows each column’s name, data type (e.g., integer, float, object), and number of non-null values.
# * Helps identify missing data and understand the type of data stored in each column.
# * Useful for planning data cleaning and preprocessing steps.

# %%
df.info() #information about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             3000 non-null   int64
#  1   gender                          3000 non-null   object
#  2   job_type                        3000 non-null   object
#  3   daily_social_media_time         2650 non-null   float64
#  4   social_platform_preference      3000 non-null   object
#  5   number_of_notifications         3000 non-null   int64
#  6   work_hours_per_day              3000 non-null   float64
#  7   perceived_productivity_score    2782 non-null   float64
#  8   actual_productivity_score       2703 non-null   float64
#  9   stress_level                    2734 non-null   float64
#  10  sleep_hours                     2684 non-null   float64
#  11  screen_time_before_sleep        2723 non-null   float64
# ...

# %% [markdown]
# ## **1.3 DataFrame Summary**
#
# The dataset consists of 3,000 observations and 17 columns, capturing information related to user demographics, job characteristics, digital habits, productivity, and wellbeing.
#
# ### **Column Composition:**
#
# * Demographic Variables:
#  age, gender, job_type
#
# * Digital Behavior & Usage:
# daily_social_media_time, social_platform_preference,
# number_of_notifications, screen_time_before_sleep
#
# * Work & Productivity Metrics:
# work_hours_per_day, perceived_productivity_score,
# actual_productivity_score, weekly_offline_hours
#
# * Wellbeing & Health Indicators:
# stress_level, sleep_hours, job_satisfaction_score,
# days_feeling_burnout_per_month
#
# **Digital Wellbeing Features:**
# * uses_focus_apps, has_digital_wellbeing_enabled
#
# ### **Data Types Overview**
#
# * **Numerical Features:**
#
#     * 12 columns (both integer and floating-point), suitable for statistical analysis and visualization.
#
# * **Categorical Features:**
#
#     * 3 columns (gender, job_type, social_platform_preference) representing qualitative attributes.
#
# * **Boolean Features:**
#
#     * 2 columns indicating digital wellbeing practices and tool usage.
#
# * **Technical Details**
#
#     * All columns are properly defined with appropriate data types.
#
#     * The DataFrame uses a RangeIndex (0–2999), ensuring efficient row access.
#
#     * Memory usage is low (~357 KB), making the dataset efficient for processing.
#
#  **Overall Interpretation**
#
#  The dataset is well-structured and analysis-ready, offering a balanced mix of behavioral, productivity, and wellbeing variables. Its design supports exploratory data analysis, visualization, and predictive modeling without structural issues.

# %% [markdown]
# # **STEP 2: Data Preprocessing**
# Data preprocessing is the stage where the raw dataset is cleaned, formatted, and transformed so that it is suitable for accurate analysis and modeling. This typically includes handling missing values, encoding categorical variables, scaling numerical features, and removing inconsistencies or outliers.

# %% [markdown]
# ## **Why Data Preprocessing Is Necessary for a Data Analysis Program**
#
# * **Improves data quality:** Real-world data often contains missing values, errors, or inconsistencies. Preprocessing cleans the data to make it reliable.
# * **Handles missing and incorrect values:** Techniques like imputation or removal prevent missing or wrong data from affecting analysis results.
# * **Ensures consistency:** Standardizing formats (dates, text, units) makes the dataset uniform and easier to work with.
# * **Removes duplicates and noise:** Eliminating redundant or irrelevant records avoids biased or misleading outcomes.
# * **Makes data suitable for analysis:** Many analytical and visualization techniques require data in a structured and clean form.
# * **Enhances accuracy of insights:** Clean data leads to more trustworthy patterns, trends, and conclusions.
# * **Improves performance:** Smaller, well-processed datasets reduce computation time and improve efficiency.
# * **Supports better visualizations:** Preprocessed data results in clearer and more meaningful charts and graphs.
# * **Prepares data for modeling:** Most statistical and machine learning models require properly cleaned and formatted input data.
#
# Overall, data preprocessing is a **crucial foundation** that ensures the analysis program produces **accurate, meaningful, and actionable insights**.

# %% [markdown]
# ## **2.1 Checking Missing Values**
#
# * The `df.isnull()` function identifies missing (`NaN`) values in the dataset.
# * Using `.sum()` calculates the total number of missing values in each column.
# * Helps detect incomplete data that may require cleaning or imputation.
# * Provides a clear overview of data quality and potential issues before analysis.

# %%
df.isnull().sum() #finding missing values
# Out:
# age                                 0
# gender                              0
# job_type                            0
# daily_social_media_time           350
# social_platform_preference          0
# number_of_notifications             0
# work_hours_per_day                  0
# perceived_productivity_score      218
# actual_productivity_score         297
# stress_level                      266
# sleep_hours                       316
# screen_time_before_sleep          277
# uses_focus_apps                     0
# has_digital_wellbeing_enabled       0
# days_feeling_burnout_per_month      0
# weekly_offline_hours                0
# job_satisfaction_score            349
# dtype: int64

# %% [markdown]
# ### **Missing Values Summary**
#
# The missing value analysis shows that several numerical columns contain null values, while most categorical and boolean fields are complete.
#
# **Columns With No Missing Values**
#
# The following variables have zero missing values, indicating complete data:
#
# * age
#
# * gender
#
# * job_type
#
# * social_platform_preference
#
# * number_of_notifications
#
# * work_hours_per_day
#
# * uses_focus_apps
#
# * has_digital_wellbeing_enabled
#
# * days_feeling_burnout_per_month
#
# * weekly_offline_hours
#
# **Columns With Missing Values**
#
#  Missing values are present primarily in time-based, productivity, and wellbeing-related metrics:
#
# * daily_social_media_time: 350 missing values
#
# * perceived_productivity_score: 218 missing values
#
# * actual_productivity_score: 297 missing values
#
# * stress_level: 266 missing values
#
# * sleep_hours: 316 missing values
#
# * screen_time_before_sleep: 277 missing values
#
# * job_satisfaction_score: 349 missing values

# %% [markdown]
# ## **2.1.1 Handling Missing Values**
#
# * Imports the NumPy library to work with numerical operations and `NaN` values.
# * Replaces empty strings (`''`) in the dataset with `NaN` to standardize missing values.
# * Removes all rows that contain any `NaN` values using `df.dropna()`.
# * Ensures the dataset is clean and free of missing data for accurate analysis and modeling.

# %%
import numpy as np
df = df.replace('', np.nan) #replacing blanks as nan
df = df.dropna()            #droping null
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4132338577.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 df = df.replace('', np.nan) #replacing blanks as nan
#       3 df = df.dropna()            #droping null
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## **2.2 Removing Duplicate Records**
#
# * The `df.drop_duplicates()` function identifies and removes duplicate rows from the dataset.
# * Ensures that each record is unique and avoids redundancy.
# * Helps maintain data integrity and prevents bias in analysis or modeling.
# * The cleaned dataset is then stored back in `df` for further processing.

# %%
df=df.drop_duplicates() #removing duplicates

# %% [markdown]
# **Duplicate Check Result:**
# * The dataset was checked for duplicate rows using `df.duplicated()` and `df.drop_duplicates()`.
# * No duplicate rows were found, indicating that each record in the dataset is unique.
# * This ensures that the analysis will not be biased or skewed by repeated entries.

# %% [markdown]
# `df.isnull().sum()` checks each column for any remaining missing (`NaN`) values after cleaning.
# * `df.shape` displays the updated number of rows and columns in the dataset.
# * Helps confirm that all missing values have been handled and provides the current dataset dimensions for analysis.

# %%
df.isnull().sum()
# Out:
# age                               0
# gender                            0
# job_type                          0
# daily_social_media_time           0
# social_platform_preference        0
# number_of_notifications           0
# work_hours_per_day                0
# perceived_productivity_score      0
# actual_productivity_score         0
# stress_level                      0
# sleep_hours                       0
# screen_time_before_sleep          0
# uses_focus_apps                   0
# has_digital_wellbeing_enabled     0
# days_feeling_burnout_per_month    0
# weekly_offline_hours              0
# job_satisfaction_score            0
# dtype: int64

# %%
df.shape
# Out:
# (1354, 17)

# %% [markdown]
# **Data Quality Summary**
#
# * The missing value check shows zero null values across all 17 columns, indicating the dataset is fully complete and clean.
#
# * After data cleaning, the dataset now contains 1,354 rows and 17 columns.
#
# * All features—demographic, digital behavior, productivity, and wellbeing variables—are available for every record.
#
# * Overall Interpretation:
# The dataset is analysis-ready, with no missing data and a consistent structure. This ensures reliable exploratory data analysis, visualization, and modeling without the need for further data cleaning or imputation steps.

# %% [markdown]
# ## **2.3 Converting Data Type**
# This code performs data type standardization and value transformation to prepare the dataset for clearer analysis and interpretation.
#
# * Categorical Data Conversion:
# A list of categorical columns (gender, job_type, social_platform_preference) is defined and converted to the category data type.
# This improves memory efficiency and ensures these variables are treated correctly during analysis and visualization.
#
# * Percentage Conversion of Score-Based Columns:
# Selected numeric columns related to productivity, stress, burnout, and job satisfaction are identified.
# Each of these columns is multiplied by 100 to convert their values into percentage format, making them more intuitive and comparable.
#
# * Rounding Values
# The transformed percentage values are rounded to two decimal places to improve readability and presentation quality.
#
# * Data Preview
# Finally, df.head() is used to display the updated DataFrame and verify that the transformations were applied correctly.

# %%
# changing data_type
cat_cols = ["gender",
"job_type",
"social_platform_preference"
]

for col in cat_cols:
    df[col] = df[col].astype('category')

columns_to_convert = [
    'perceived_productivity_score',
    'actual_productivity_score',
    'job_satisfaction_score',
    'stress_level',
    'days_feeling_burnout_per_month'
]

# Convert these columns to percentage
for col in columns_to_convert:
    df[col] = df[col] * 100

#  Round the values to 2 decimal places
df[columns_to_convert] = df[columns_to_convert].round(2)

# Show updated dataframe
df.head()
# Out:
#     age  gender job_type  daily_social_media_time social_platform_preference  \
# 3    42  Female  Finance                 3.075394                   Telegram
# 7    33    Male       IT                 2.878584                    Twitter
# 11   39    Male       IT                 2.148682                    Twitter
# 14   47    Male  Student                 1.717422                   Facebook
# 15   26  Female       IT                 7.012937                   Telegram
#
#     number_of_notifications  work_hours_per_day  perceived_productivity_score  \
# 3                        61            7.717358                        894.70
# 7                        52            7.452186                        689.30
# 11                       53            9.550245                        746.50
# 14                       54            9.959630                        490.07
# 15                       61            6.185177                        674.57
#
# ...

# %% [markdown]
# **Insights: Why These Conversions Are Important**
#
# * Improved Interpretability: Converting normalized scores into percentages makes results easier to understand and explain to non-technical stakeholders.
#
# * Consistent Scaling: Percentage values bring multiple score-based metrics onto a common scale, enabling fair comparison across features.
#
# * Efficient Data Handling: Using the category data type reduces memory usage and speeds up group-based operations.
#
# * Better Visualizations: Charts and summaries become clearer and more meaningful when categorical variables and percentages are properly defined.

# %% [markdown]
# **Purpose of Checking df.info()**
#
# After performing data type conversions and value transformations, df.info() is used to verify that the changes have been applied correctly. This step helps confirm that categorical variables are stored as category, numerical scores remain in the correct numeric format, boolean indicators are unchanged, and that the dataset contains no missing values. Checking df.info() ensures the dataset is properly structured, memory-efficient, and ready for accurate analysis and visualization.

# %%
df.info()
print("Successfully converted the data types as mentioned above!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2438806668.py in <cell line: 0>()
# ----> 1 df.info()
#       2 print("successfully converted data types")
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Updated DataFrame Summary (After Conversion)**
#
# The dataset contains 1,354 records and 17 columns, with no missing values. All features use appropriate and optimized data types, making the data clean and analysis-ready.
#
# * Categorical (3): gender, job_type, social_platform_preference
#
# * Numerical (12):
#
#     * Integer (3): age, number_of_notifications, days_feeling_burnout_per_month
#
#     * Float (9): daily_social_media_time, work_hours_per_day, perceived_productivity_score, actual_productivity_score, stress_level, sleep_hours, screen_time_before_sleep, weekly_offline_hours, job_satisfaction_score
#
# * Boolean (2): uses_focus_apps, has_digital_wellbeing_enabled
#
# Memory usage is reduced to ~144.7 KB, reflecting efficient data handling. Overall, the dataset is well-structured, optimized, and ready for exploratory analysis and modeling.

# %% [markdown]
# **Final Missing Value Validation:**
#
# * The `df.isnull().sum()` function is executed again on the updated dataset.
# * It calculates the total number of missing (`NaN`) values in each column.
# * This step verifies the effectiveness of the previous data cleaning and imputation processes.
# * It ensures that no unexpected missing values remain after preprocessing.
# * This final validation confirms that the dataset is clean and ready for analysis or modeling.

# %%
df.isnull().sum()
# Out:
# age                               0
# gender                            0
# job_type                          0
# daily_social_media_time           0
# social_platform_preference        0
# number_of_notifications           0
# work_hours_per_day                0
# perceived_productivity_score      0
# actual_productivity_score         0
# stress_level                      0
# sleep_hours                       0
# screen_time_before_sleep          0
# uses_focus_apps                   0
# has_digital_wellbeing_enabled     0
# days_feeling_burnout_per_month    0
# weekly_offline_hours              0
# job_satisfaction_score            0
# dtype: int64

# %% [markdown]
# **No Missing Values in Dataset:**
#
# * Executing `df.isnull().sum()` returned **0 for all columns**, indicating that there are **no missing (`NaN`) values** in the dataset.
# * This confirms that all previous data cleaning steps (type conversion, mean imputation, placeholder replacement, etc.) were applied successfully.
# * A dataset without missing values ensures **data integrity** and avoids errors in analysis, visualization, or modeling.
# * It indicates the dataset is now **complete and ready for further processing or exploration**.

# %% [markdown]
# ## **2.4 Handling Zero Values in Numerical Columns**
#
# **Objective**:
# Certain numerical columns contain zero values that do not represent valid or realistic measurements. If left untreated, these values can distort statistical summaries and analytical results.
# Before applying this transformation, the dataset included zero values in key productivity, wellbeing, and digital usage columns. These zeros could negatively impact mean calculations, trends, and visual interpretations, leading to biased insights.
#
# **Code Logic Explanation**
#
# * A list of columns requiring correction is defined.
#
# * For each column:
#
# * Zero values (0) are treated as missing data by replacing them with NaN.
#
# * The mean value of the column is calculated while excluding missing values.
#
# * All zero entries are then replaced with the computed mean, preserving data consistency.
# This ensures that unrealistic zero values do not skew the dataset.

# %%
cols_to_fix =[ "daily_social_media_time",
  "number_of_notifications","work_hours_per_day",
  "perceived_productivity_score" , "actual_productivity_score",
  "stress_level","sleep_hours","screen_time_before_sleep" ,  "uses_focus_apps"  ,
  "has_digital_wellbeing_enabled" , "days_feeling_burnout_per_month",
  "weekly_offline_hours",
  "job_satisfaction_score"]

for col in cols_to_fix:
    mean_value = df[col].replace(0, pd.NA).mean()  # Treat 0 as missing
    df[col] = df[col].replace(0, mean_value)

# %% [markdown]
# **After running the code:**
#
# * All invalid zero values are replaced with meaningful average values.
#
# * The numerical distributions become more balanced and representative.
#
# * The dataset remains complete, with no missing values.
#
# * Subsequent analysis and visualizations produce more accurate and trustworthy results.
#
# **Final Insight:**
# Replacing invalid zero values with column means enhances data quality, reliability, and analytical accuracy, making the dataset well-prepared for exploratory analysis and modeling.

# %% [markdown]
# #**Display the last 5 rows of the Dataset.**
#
# **Viewing the Last Rows of the Dataset**
#
# * The `df.tail()` function is used to display the last **5 rows** of the DataFrame by default.
# * It provides a quick view of the most recent entries in the dataset.
# * Useful for verifying recent data transformations, additions, or cleaning steps.
# * Helps in inspecting whether preprocessing operations (like type conversions, missing value handling, or replacements) have been applied correctly.
# * Can optionally take an integer argument (e.g., `df.tail(10)`) to display a specific number of last rows.

# %%
df.tail() #displaying the last 5 rows of the dataset.
# Out:
#       age  gender   job_type  daily_social_media_time  \
# 2992   21  Female  Education                 2.935349
# 2993   34    Male    Student                 0.801187
# 2994   27    Male     Health                 5.032686
# 2995   30    Male    Student                 5.369745
# 2996   32    Male    Student                 4.149257
#
#      social_platform_preference  number_of_notifications  work_hours_per_day  \
# 2992                   Facebook                       67           10.985670
# 2993                     TikTok                       66            9.393322
# 2994                   Telegram                       51            4.461574
# 2995                   Facebook                       59            6.059340
# 2996                   Telegram                       41            8.846446
#
#       perceived_productivity_score  actual_productivity_score  stress_level  \
# 2992                        709.20                     604.48         200.0
# ...

# %% [markdown]
# **Summary After Executing df.tail()**
#
# After executing the df.tail() command, the last five records of the dataset are displayed, providing a final snapshot of the data. This output confirms that all preprocessing steps—such as data cleaning, data type conversion, handling missing or zero values, and scaling—have been applied consistently across the dataset. The values appear properly formatted, categorical fields are readable, and numerical columns reflect realistic and cleaned values. Overall, this step serves as a final validation check, ensuring the dataset is well-structured and ready for exploratory analysis, visualization, or modeling.

# %% [markdown]
# ### **Index Reset and Dataset Reorganization:**
#
# * The DataFrame index is reset to restore a continuous, sequential order.
# * `drop=True` removes the existing index instead of adding it as a new column.
# * This operation ensures that the index starts from zero and increments uniformly.
# * It is particularly useful after row deletions or filtering operations.
# * Resetting the index improves data consistency and avoids misalignment issues in subsequent analysis or modeling steps.

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ##**Exporting and Downloading the Cleaned Dataset**
#
# * The `files` module from `google.colab` is imported to enable file download functionality within Colab.
# * The DataFrame `df` is saved as a CSV file named **'cleaned_file.csv'** using `df.to_csv()`.
# * The parameter `index=False` ensures that the DataFrame index is not included in the CSV file.
# * `files.download('cleaned_file.csv')` triggers a download of the cleaned CSV file to the local machine.
# * This step allows users to preserve and share the cleaned dataset for further analysis or reporting.

# %%
from google.colab import files

# Save your DataFrame as CSV
df.to_csv('cleaned_file.csv', index=False)

# Download the CSV
files.download('cleaned_file.csv')
print("Cleaned file downloaded successfully")

# %% [markdown]
# # **STEP 3 : EDA And Visualization**

# %% [markdown]
# ## **3.1 Exploratory Data Analysis (EDA)**
#
# * **Exploratory Data Analysis (EDA)** is the process of examining and understanding a dataset before applying advanced analysis or modeling techniques.
# * It helps identify **patterns, trends, and relationships** within the data.
# * EDA detects **missing values, outliers, and inconsistencies** that may affect results.
# * Statistical summaries (mean, median, count, etc.) are used to understand **data distribution**.
# * Visualizations such as **histograms, box plots, bar charts, and heatmaps** make insights easier to interpret.
# * EDA supports **feature selection** by identifying important variables.
# * It validates assumptions and guides the **choice of analytical methods**.
# * EDA improves **decision-making** by providing a clear picture of the data structure.
# * Overall, EDA is a **crucial step** that transforms raw data into **meaningful insights** and lays a strong foundation for accurate data analysis.

# %% [markdown]
# ## **3.1.1 Separating Numeric and Categorical Columns**
#
# * `df.select_dtypes()` is used to select columns based on their data type.
# * `num_cols = df.select_dtypes(include=['int64','float64'])` extracts all **numeric columns** (integers and floats) from the DataFrame.
# * `cat_cols = df.select_dtypes(include=['object','bool'])` extracts all **categorical columns** (strings and boolean values) from the DataFrame.
# * This separation allows for **targeted analysis and preprocessing**, as numeric and categorical data often require different handling techniques.
# * Organizing columns by type facilitates tasks like statistical analysis, visualization, and feature engineering.

# %%
num_cols = df.select_dtypes(include=['int64','float64'])
cat_cols = df.select_dtypes(include=['category','bool'])

# %% [markdown]
# **Result**
#
# Numerical columns identified:
# * age
# * daily_social_media_time
# * number_of_notifications
# * work_hours_per_day
# * perceived_productivity_score
# * actual_productivity_score
# * stress_level
# * sleep_hours
# * screen_time_before_sleep
# * days_feeling_burnout_per_month
# * weekly_offline_hours
# * job_satisfaction_score
#
# **Categorical columns identified:**
# * gender
# * job_type
# * social_platform_preference
# Boolean Columns:
# * Boolean columns identified:
# * uses_focus_apps
# * has_digital_wellbeing_enabled

# %% [markdown]
# ## **3.1.2 Descrptive Statistics**
# **Purpose of Descriptive Statistics (Numerical EDA)**
#
# Before performing visual analysis or modeling, it is essential to understand the basic statistical characteristics of numerical features. Descriptive statistics provide a high-level overview of data distribution, central tendency, and variability, helping identify patterns, anomalies, and potential scaling issues.
#
# **Code Explanation:**
#
# * The describe() function generates summary statistics for all numerical columns in the dataset, including:
#
# * Count of observations
#
# * Mean (average)
#
# * Standard deviation (spread of values)
#
# * Minimum and maximum values
#
# * Quartiles (25%, 50%, 75%)
#
# This step helps in assessing data consistency and readiness for further analysis.

# %%
num_cols.describe()
# Out:
#                age  daily_social_media_time  number_of_notifications  \
# count  1354.000000              1354.000000              1354.000000
# mean     41.278434                 3.391418                59.899557
# std      14.037223                 1.854076                 7.704748
# min      18.000000                 0.016741                34.000000
# 25%      29.000000                 2.087307                55.000000
# 50%      41.000000                 3.391418                60.000000
# 75%      54.000000                 4.431413                65.000000
# max      65.000000                16.975665                87.000000
#
#        work_hours_per_day  perceived_productivity_score  \
# count         1354.000000                   1354.000000
# mean             6.865947                    549.245081
# std              1.989705                    200.234130
# min              0.137869                    200.680000
# 25%              5.547851                    378.482500
# ...

# %% [markdown]
# **Interpretation After Execution**
#
# * All numerical columns contain 1,354 valid observations, confirming data completeness.
#
# * Central tendency measures (mean and median) provide insight into typical user behavior, such as average age, work hours, sleep duration, and social media usage.
#
# * Variability (standard deviation) highlights differences in user habits, particularly in productivity scores, stress levels, and burnout indicators.
#
# * Quartile values reveal the spread and distribution of data, helping detect skewness and outliers.
#
# * Minimum and maximum values confirm that numerical ranges are realistic and logically valid.

# %% [markdown]
# # **📊3.2 Visualization Phase**

# %% [markdown]
# ### **Importing Libraries for Data Analysis and Visualization**
#
# * `import pandas as pd` – Imports the **pandas** library, used for data manipulation, analysis, and handling tabular datasets (DataFrames).
# * `import matplotlib.pyplot as plt` – Imports **Matplotlib’s Pyplot** module, which is used for creating static, high-quality visualizations such as line plots, bar charts, and histograms.
# * `import seaborn as sns` – Imports **Seaborn**, a higher-level visualization library built on Matplotlib, providing aesthetically pleasing and informative statistical graphics.
# * Together, these libraries form the **core toolkit for data exploration, visualization, and analysis in Python**.

# %%
# Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Seaborn Style Setting**
# - `sns.set(style="whitegrid")` applies the **whitegrid** theme to Seaborn plots.
# - It sets a white background with light grid lines on the plotting area.
# - This improves readability of values and makes it easier to compare points against the grid.
# - The style is applied globally, so all plots created after this line will use whitegrid unless changed again.

# %%
# Set Seaborn style
sns.set(style="whitegrid")

# %% [markdown]
# ## **3.2.1 Univariate Analysis**
# Univariate analysis focuses on examining one variable at a time to understand its distribution, central tendency, spread, and overall behavior. It helps identify patterns, skewness, and potential outliers, forming a strong foundation for bivariate and multivariate analysis.
#
# **1. Histogram: Daily Social Media Time**
#
# * Used to understand the distribution and frequency of daily social media usage.
#
# * Helps identify common usage ranges, skewness, and extreme usage patterns.
#
# **2. Boxplot: Perceived Productivity Score**
#
# * Summarizes the median, interquartile range, and variability of productivity scores.
#
# * Useful for detecting outliers and overall spread in perceived productivity.
#
# **3. Violin Plot: Stress Level**
#
# * Combines distribution and density to show how stress levels are spread across individuals.
#
# * Highlights concentration of values, median, and possible skewness.
#
# **4. Count Plot: Gender**
#
# * Displays the frequency of categorical values in the gender variable.
#
# * Helps assess category balance, which is important before performing comparative analysis.

# %% [markdown]
# ## **HISTOGRAM**
#
# * To perform univariate analysis of the variable daily_social_media_time (study one variable at a time).
# ​
#
# * To visualize the frequency/density of different hour ranges using a histogram with 20 bins.
# ​
#
# * To add a KDE curve so the distribution shape is smoother and easier to interpret than bars alone.
# ​

# %%
# 1. Histogram: Daily Social Media Time
plt.figure(figsize=(8,5))
sns.histplot(df['daily_social_media_time'], bins=20, kde=True, color='blue')
plt.title('Distribution of Daily Social Media Time')
plt.xlabel('Hours')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# **Key insights from the Visualization**
#
# * The distribution is right‑skewed: most users spend a modest number of hours, with a few heavy users at very high values.
# ​
#
# * The highest density (peak) is around 2–4 hours per day, indicating this is the most common usage range.
# ​
#
# * There are some extreme values above about 8–10 hours, suggesting possible outliers or a small group of very high social‑media users.

# %% [markdown]
# ## **2.BOX PLOT**
# * To perform univariate analysis of perceived_productivity_score (study its distribution using a single summary plot).
#
# * To show the median productivity score (central tendency) clearly.
#
# * To visualize the spread/variability of scores via the interquartile range (the height of the box).
#
# * To indicate the overall range of typical scores using the whiskers (from lower to upper non‑outlier values).
#
# * To quickly detect any outliers in productivity scores (points outside the whiskers, if present).

# %%
# 2. Boxplot of perceived_productivity_score
plt.figure(figsize=(6,5))   # increase size
sns.boxplot(y=df['perceived_productivity_score'],color='skyblue')
plt.title('Boxplot: Perceived Productivity Score')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# **Insights from the plot**
# * Median perceived productivity is around the mid‑range of the scale (roughly near the center of 200–900), suggesting an average or moderate self‑rated productivity.
#
# * The box (IQR) spans roughly from about 380 to 720, meaning the middle 50% of respondents cluster in this band.
#
# * The total range of usual scores is about 200 to 900, showing fairly high variability in how productive people feel.
#
# * Since the median is slightly above the center of the box, there might be a mild skew, with more respondents having somewhat lower scores than higher ones (or vice‑versa, depending on exact position).

# %% [markdown]
# ## **3.COUNT PLOT**
# * his code creates a count plot to visualize the distribution of customers by gender in the dataset.
#
# * sns.countplot() counts the number of records for each gender category (Female, Male, Other).
#
# * hue='gender' applies different colors to each gender for clearer distinction.
#
# * The plot helps in understanding the categorical balance of the dataset before deeper analysis.

# %%
# 3. Countplot: Gender
plt.figure(figsize=(6,4))
sns.countplot(x='gender', data=df, palette='pastel',legend=False,hue='gender')
plt.title('Count by Gender')
plt.show()

# %% [markdown]
# **Key Insights from the Visualization**
#
# * Male and Female categories dominate the dataset, indicating a relatively balanced representation between them.
#
# * The Male count is slightly higher than the Female count.
#
# * The “Other” gender category is significantly underrepresented, with very few records.
#
# * This imbalance suggests that gender-based analysis may be reliable mainly for Male and Female groups, while insights for the “Other” category may be limited due to low sample size.
#
# * Overall, this plot provides a quick demographic overview and helps assess whether gender distribution could influence further analytical results.

# %% [markdown]
# ## **4.Violin Plot: Stress Level**
#
# * This code generates a violin plot to visualize the distribution and density of the stress_level variable.
#
# * The violin plot combines a box plot and kernel density plot, showing spread, median, and concentration of values.
#
# * It helps identify variability, central tendency, and possible skewness in stress levels.
#
# * The plot is useful for understanding how stress values are distributed across the dataset.

# %%
# 4. Violin Plot: Stress Level
plt.figure(figsize=(7,5))
sns.violinplot(y=df['stress_level'], color='lightgreen')
plt.title('Distribution of Stress Level')
plt.ylabel('Stress Level')
plt.show()

# %% [markdown]
# **Key Insights from the Visualization**
#
# * Stress levels are widely spread, indicating high variability among individuals.
#
# * The median stress level lies near the center, suggesting a moderate overall stress tendency.
#
# * The wider sections of the violin show where stress values are most concentrated.
#
# * Slight asymmetry in the shape indicates potential skewness, meaning stress is not evenly distributed.
#
# * Presence of long tails suggests some individuals experience very low or very high stress levels.
#
# * Overall, this plot highlights the diversity in stress experiences and supports further analysis on factors influencing stress levels.

# %% [markdown]
# ## **Final Univariate Analysis Summary**
#
# These visualizations together help understand how individual variables behave and how they set the foundation for interpreting relationships in Univariate analysis.
#
# **1. Histogram: Daily Social Media Time**
#
# * Shows the distribution of daily social media usage hours.
#
# * Most users spend a moderate amount of time (around 2–5 hours) on social media.
#
# * The distribution is right-skewed, indicating a small group of users with very high usage.
#
# * This skewness suggests that excessive social media usage may act as a key influencing factor when compared with productivity or stress levels.
#
# **2. Boxplot: Perceived Productivity Score**
#
# * Displays the spread and central tendency of perceived productivity scores.
#
# * The median score lies near the mid-range, indicating average perceived productivity for most users.
#
# * A wide interquartile range reflects significant variation in how individuals perceive their productivity.
#
# * Presence of extreme values suggests that productivity perception varies notably across individuals, making it useful for comparison with stress or social media usage.
#
# **3. Violin Plot: Stress Level**
#
# * Illustrates the distribution and density of stress levels across users.
#
# * The widest sections indicate where stress values are most concentrated.
#
# * Stress levels show high variability, with both low and high extremes present.
#
# * Slight asymmetry suggests skewness, meaning stress is unevenly distributed among users.
#
# * This variation makes stress a strong candidate for bivariate comparison with productivity and screen-time variables.
#
# **4. Count Plot: Gender**
#
# * Shows the categorical distribution of users by gender.
#
# * Male and Female categories are nearly balanced, enabling meaningful gender-based comparisons.
#
# * The “Other” category has very few observations, limiting strong bivariate conclusions for this group.
#
# * Gender can still be explored as a grouping variable when analyzing productivity or stress patterns.
#
# **Overall Analytical Insight**
#
# * These plots establish a clear understanding of data distribution, variability, and imbalance.
#
# * High variability in stress and productivity, along with skewed social media usage, suggests meaningful patterns may emerge when variables are analyzed together.
#
# * This univariate groundwork strengthens the interpretation of bivariate relationships such as:
#
#   * Social media time vs productivity
#
#   * Stress level vs perceived productivity
#
#   * Gender-based differences in stress or productivity

# %% [markdown]
# # **3.2.2 Bivariate Analysis**
# Bivariate analysis studies the relationship between two variables to understand how one variable affects or relates to another. It helps identify correlations, trends, patterns, or differences in the data. This is a key part of exploratory data analysis (EDA).
# 1. Scatter Plot: Work Hours vs Perceived Productivity by Gender
#
#     - Purpose: Examine how work hours relate to perceived productivity, and observe patterns across genders.
#
# 2. Box Plot: Actual Productivity by Job Type
#
#     - Purpose: Compare actual productivity scores across different job types.
#
# 3. Bar Plot: Average Social Media Time by Gender
#
#    - Purpose: Compare average daily social media usage across gender groups.

# %% [markdown]
# ## **1.SCATTER PLOT**
#
# * Visualizes the relationship between daily work hours and perceived productivity score.
#
# * Uses a scatter plot to observe individual-level variations.
#
# * Differentiates data points by gender using color (hue='gender').
#
# * Helps identify patterns, trends, or differences in productivity perception across genders.
#
# * Supports exploratory data analysis (EDA) to check correlation or dispersion.

# %%
# 5. Scatterplot: Work Hours vs Productivity
plt.figure(figsize=(10,6))
sns.scatterplot(x='work_hours_per_day', y='perceived_productivity_score',
                hue='gender', data=df, palette='bright')
plt.title('Work Hours vs Perceived Productivity by Gender')
plt.show()

# %% [markdown]
#  **Key Insights from the Plot**
#
# * No strong linear relationship: Productivity scores are widely scattered across all work-hour ranges.
#
# * Peak concentration: Most individuals work around 5–8 hours per day, with productivity scores spread broadly.
#
# * Gender overlap: Male, Female, and Other categories show similar distribution patterns, indicating no clear gender-based separation.
#
# * High variability: For the same number of work hours, perceived productivity varies significantly.
#
# * Outliers present: Some individuals report very high or very low productivity regardless of work hours.

# %% [markdown]
# ## **BOX PLOT**
#
# * Visualizes actual productivity scores across different job types using a boxplot.
#
# * Compares the distribution, median, and spread of productivity for each job category.
#
# * Helps identify variability, central tendency, and outliers within each job type.
#
# * Supports comparative analysis to understand how job roles differ in productivity levels.

# %%
# 6. Boxplot: Productivity by Job Type
plt.figure(figsize=(10,5))
sns.boxplot(x='job_type', y='actual_productivity_score', data=df, palette='Set2',hue='job_type',legend=False)
plt.title('Actual Productivity by Job Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Key Insights from the Plot**
#
# * Similar medians across job types: Most job categories show median productivity around the mid-range, indicating comparable overall performance.
#
# * Finance and IT roles tend to have slightly higher median productivity than others.
#
# * Students show a lower median and wider variability, suggesting inconsistent productivity levels.
#
# * Unemployed group has a wide spread, indicating high variability in productivity scores.
#
# * Outliers present in all job types, showing individual differences regardless of profession.
#
# * Overlapping distributions suggest job type alone does not strongly determine actual productivity.

# %% [markdown]
# ## **BAR PLOT**
#
# * Visualizes the average daily social media usage time across different gender groups.
#
# * Uses a bar plot to compare mean values clearly.
#
# * Applies gender-based coloring (hue) to enhance category distinction.
#
# * Helps identify differences in social media behavior among genders.
#
# * Supports descriptive EDA for behavioral analysis.

# %%
# 7. Barplot: Average Social Media Time by Gender
plt.figure(figsize=(10,5))
sns.barplot(x='gender', y='daily_social_media_time', data=df, palette='deep',hue='gender',legend=False)
plt.title('Average Social Media Time by Gender')
plt.show()

# %% [markdown]
# **Key Insights from the Plot**
#
# * Similar usage for Female and Male: Both groups show nearly equal average daily social media time.
#
# * Higher average for “Other”: The “Other” gender category has a slightly higher mean usage.
#
# * Variability indication: Error bars suggest more variation in social media time within the “Other” group.
#
# * No extreme gap: Overall differences between genders are moderate rather than drastic.
#
# * Behavioral consistency: Social media usage appears relatively consistent across major gender groups.

# %% [markdown]
# ##**Final Bivariate Analysis Summary**
#
# * Scatterplot: Work Hours vs Perceived Productivity by Gender
#
#     - No strong correlation between work hours and perceived productivity.
#
#     - Most people work 5–8 hours/day with widely varying productivity scores.
#
#     - Gender shows no clear effect; distributions overlap.
#
#     - High variability and some outliers present.
#
# * Boxplot: Actual Productivity by Job Type
#
#     - Median productivity similar across job types; Finance and IT slightly higher.
#
#     - Students and Unemployed show more variability.
#
#     - Outliers exist in all categories.
#
#     - Job type alone does not strongly determine productivity.
#
# * Barplot: Average Social Media Time by Gender
#
#     - Female and Male have similar average social media usage.
#
#     - “Other” category slightly higher and more variable.
#
#     - Gender has minor effect on social media time.

# %% [markdown]
# # **3.2.3 Multivariate Analysis**
# Multivariate analysis is a statistical approach used to analyze and understand relationships among three or more variables simultaneously. Unlike univariate or bivariate analysis, it captures complex interactions, patterns, and dependencies between multiple factors, making it especially useful for studying real-world behaviors such as the combined impact of social media usage, lifestyle habits, and productivity.
#
# **Multivariate Analysis Using Different Plots**
# * Correlation Heatmap – Productivity Correlations
# Shows the strength and direction of linear relationships between all selected variables simultaneously. It helps quickly identify strong, weak, or negligible associations, especially between social media usage and productivity scores.
#
# * Pairplot – Productivity Relationships by Gender
# Displays pairwise relationships among multiple numerical variables at once. It helps identify distribution patterns, potential relationships, and gender-based variations in social media usage and productivity metrics.
#
# * Clustermap – Clustered Correlation Heatmap of Productivity Variables
# Applies hierarchical clustering to group variables with similar correlation patterns. It reveals natural groupings, distinguishing productivity-related variables from lifestyle and social media behaviors.

# %% [markdown]
# ## **CORRELATION HEATMAP**
#
# * Selects key numerical productivity and lifestyle variables for analysis.
#
# * Computes the Pearson correlation matrix to measure linear relationships.
#
# * Visualizes correlations using a heatmap with annotated values.
#
# * Uses a diverging color scale centered at zero to clearly distinguish positive and negative relationships.
#
# * Supports Exploratory Data Analysis (EDA) by quickly identifying strong and weak associations among variables.

# %%
# 8. Correlation Heatmap (Numeric columns)
plt.figure(figsize=(10,6))
numeric_cols = ['daily_social_media_time', 'work_hours_per_day', 'sleep_hours',
                'perceived_productivity_score', 'actual_productivity_score',
                'stress_level', 'screen_time_before_sleep']
corr = df[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", center=0)
plt.title('Productivity Correlations')
plt.show()

# %% [markdown]
# **Key Insights from the Visualization**
#
# * Perceived productivity score and actual productivity score show a very strong positive correlation (~0.96), indicating high consistency between self-reported and actual productivity.
#
# * Most lifestyle variables (daily social media time, sleep hours, screen time before sleep) show very weak or near-zero correlations with productivity scores.
#
# * Work hours per day has minimal correlation with both perceived and actual productivity, suggesting longer hours do not directly imply higher productivity.
#
# * Stress level shows a slight negative or negligible relationship with productivity, indicating limited linear impact.
#
# * Overall, the heatmap confirms that strong linear relationships are rare, and productivity is influenced by multiple factors beyond simple time-based metrics.

# %% [markdown]
# ## **PAIR PLOT**
# * Creates a pairplot of the first four numerical variables to visualize pairwise relationships.
#
# * Displays scatter plots for every numerical variable combination.
#
# * Shows KDE (density) plots on the diagonal to understand individual distributions.
#
# * Uses gender as a hue to compare patterns across Female, Male, and Other groups.
#
# * Helps in exploratory data analysis (EDA) to detect relationships, trends, and group-wise differences in productivity-related metrics.

# %%
# 9. Pairplot (Key numeric vars + gender)
sns.pairplot(df[numeric_cols[:4] + ['gender']], hue='gender', palette='bright',
             diag_kind='kde')
plt.suptitle('Productivity Relationships by Gender', y=1.02)
plt.show()

# %% [markdown]
# **Key Insights from the Visualization**
#
#
# * Distributions overlap heavily across genders, indicating no strong gender-based separation in productivity metrics.
#
#
# * Diagonal KDE plots show similar distribution shapes for all genders, suggesting comparable ranges and central tendencies.
#
#
# * Scatter plots reveal weak to moderate relationships between variables such as work hours, sleep hours, and productivity scores.
#
#
# * No clear linear correlation dominates between most variable pairs.
#
#
# * Perceived productivity score appears widely spread, indicating varied self-assessment across individuals regardless of gender.
#
#
# * Overall, gender does not strongly influence productivity patterns, and variations are more individual-driven than group-driven.

# %% [markdown]
# ## **CLUSTERMAP**
#
# * Computes the correlation matrix for key productivity-related numerical variables.
#
# * Uses a clustermap to apply hierarchical clustering on both rows and columns.
#
# * Groups variables based on similar correlation patterns, not just individual values.
#
# * Displays a heatmap with annotations to clearly show correlation strengths.
#
# * Adds dendrograms to visualize how variables are clustered together.
#
# * Supports advanced EDA by revealing hidden structure among productivity metrics.

# %%
# 10 Clustermap - Hierarchical Clustering of Productivity Metrics
plt.figure(figsize=(12,10))
numeric_cols = ['daily_social_media_time', 'work_hours_per_day', 'sleep_hours',
                'perceived_productivity_score', 'actual_productivity_score',
                'stress_level', 'screen_time_before_sleep']

# Cluster rows (observations) and columns (variables)
sns.clustermap(df[numeric_cols].corr(),
               annot=True, cmap='coolwarm', fmt=".2f",
               linewidths=0.5, figsize=(12,8),
               dendrogram_ratio=0.1)
plt.title('Clustered Correlation Heatmap: Productivity Variables')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Key Insights from the Visualization**
#
# * Perceived productivity score and actual productivity score form a strong cluster with a very high positive correlation (~0.96), indicating strong alignment between self-reported and measured productivity.
#
# * Most other variables show very weak or near-zero correlations, suggesting limited linear relationships.
#
# * Daily social media time, screen time before sleep, and sleep hours cluster together, reflecting related lifestyle behaviors.
#
# * Work hours per day and stress level show minimal correlation with productivity scores, implying productivity is not solely driven by longer working hours or stress.
#
# * The clustering confirms that productivity metrics are more closely related to each other than to lifestyle or time-usage variables.

# %% [markdown]
# ##**Final Multivariate Analysis Summary: Social Media & Productivity**
# * Correlation Heatmap – Productivity Correlations
# Highlights linear relationships among variables. A strong positive correlation exists between perceived and actual productivity, while social media time, sleep, and work hours show very weak relationships with productivity.
# * Pairplot – Productivity Relationships by Gender
# Shows interactions among multiple variables with gender as a grouping factor. Patterns largely overlap across genders, indicating no strong gender-based differences in productivity or social media usage.
#
# * Clustermap – Clustered Correlation Heatmap: Productivity Variables
# Groups variables based on similarity. Productivity scores cluster together, while social media, sleep, and screen-time variables form a separate lifestyle cluster, indicating indirect influence.
#
# **Overall Insight:**
# Productivity measures are strongly aligned with each other, whereas social media usage and lifestyle variables show minimal direct impact on productivity in a multivariate context.
